# %%
from matplotlib import pyplot as plt
import numpy as np
from matplotlib_venn import venn2

v = venn2(subsets = [set([2,6,5,2,7,9,2,5]), set([2,6,34,3,2,6])] ,set_labels=('A,', 'B'))
plt.title('venndiagram')
plt.show(v)
